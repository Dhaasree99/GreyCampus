# %% [markdown]
# # Logistic Regression Project

# %% [raw]
# Done by: S.Dhanasree

# %% [raw]
# Here, We will try to create a model that will predict whether or not the user will click on an ad based on the features of the user.

# %%
#importing all the libraries required

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the file into data1 variable

# %%
data1=pd.read_csv("C:/Users/LENOVO/Desktop/PSR/Sweety/Datasets/advertising.csv")
data1.describe()
#describe() method gives the total outline of the data
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
#listing out all the columns present in the data1

# %%
data1.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
#head() gives the first 5 columns of the dataset here i am visualizing the first 10 columns

# %%
data1.head(10)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
# 5                     59.99   23     59761.56                226.74
# 6                     88.91   33     53852.85                208.36
# 7                     66.00   48     24593.33                131.76
# 8                     74.53   30     68862.00                221.51
# 9                     69.88   20     55642.32                183.82
#
#                            Ad Topic Line              City  Male     Country  \
# 0     Cloned 5thgeneration orchestration       Wrightburgh     0     Tunisia
# ...

# %%
#info() gives the columns and its values info and shows it it has null values are not

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
#This data doesnot contain any null values

# %%
#Analyzing the data for the further process

# %%
sns.histplot(x="Age",bins=data1.Age.nunique(),data=data1)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#I here analyzed which age group people are more it is between 25-40

# %%
sns.scatterplot(x="Daily Time Spent on Site",y="Age",hue="Clicked on Ad",data=data1)
# Out:
# <AxesSubplot:xlabel='Daily Time Spent on Site', ylabel='Age'>

# %%
#From the graph it is clear that the people of age group between 20-40 spend most of their time 
#on the site compared to other age groups

#But the people who mostly clicked on the Ad spent less time and are in all age groups

# %%
sns.histplot(x="Daily Internet Usage",hue="Clicked on Ad",data=data1)
# Out:
# <AxesSubplot:xlabel='Daily Internet Usage', ylabel='Count'>

# %%
#The less people whose internet usage is less have clicked on the Ad more than those who use more data

# %%
sns.countplot(x="Male",hue="Clicked on Ad",data=data1)
# Out:
# <AxesSubplot:xlabel='Male', ylabel='count'>

# %%
#Both male and female played almost equal role in clicking the  but the female seems slightly more

# %%
data1.groupby(['Country','Clicked on Ad']).describe()
# Out:
#                           Daily Time Spent on Site                        \
#                                              count       mean        std
# Country     Clicked on Ad
# Afghanistan 0                                  3.0  75.703333   7.109215
#             1                                  5.0  58.230000  13.469894
# Albania     0                                  3.0  77.646667   4.175755
#             1                                  4.0  52.665000  16.312961
# Algeria     0                                  3.0  75.923333   4.776550
# ...                                            ...        ...        ...
# Yemen       1                                  2.0  61.600000  15.952329
# Zambia      0                                  1.0  88.720000        NaN
#             1                                  3.0  51.386667   1.373511
# Zimbabwe    0                                  2.0  82.770000   1.711198
# ...

# %%
#It seems all the countries played same role in clicking the Ad

# %%
data1.groupby(['City', 'Clicked on Ad']).describe()
# Out:
#                             Daily Time Spent on Site                           \
#                                                count   mean std    min    25%
# City          Clicked on Ad
# Adamsbury     1                                  1.0  40.19 NaN  40.19  40.19
# Adamside      1                                  1.0  45.82 NaN  45.82  45.82
# Adamsstad     0                                  1.0  81.05 NaN  81.05  81.05
# Alanview      0                                  1.0  83.26 NaN  83.26  83.26
# Alexanderfurt 1                                  1.0  46.37 NaN  46.37  46.37
# ...                                              ...    ...  ..    ...    ...
# Youngburgh    0                                  1.0  63.60 NaN  63.60  63.60
# Youngfort     1                                  1.0  62.95 NaN  62.95  62.95
# Yuton         1                                  1.0  47.48 NaN  47.48  47.48
# Zacharystad   0                                  1.0  64.24 NaN  64.24  64.24
# ...

# %%
#It seems all the cities also played same role in clicking the Ad

# %%
sns.heatmap(data1.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#Daily time spent on site is mostly correlated with our target variable clicked on Ad .
#And all other are non-collinear.

# %%
#Here I am splitting the data into x and y by removing the unwanted columns.

# %%
x=data1.drop(['Area Income','Ad Topic Line', 'City','Country','Timestamp', 'Clicked on Ad'],axis=1)
y=data1['Clicked on Ad']

# %%
#Here i removed few columns that i felt like are not needed.

# %%
#Here i am importing the train test and split method for splitting the data into traina and test.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#Here i am importing the logistic regression algorithm for the building the model

# %%
from sklearn.linear_model import LogisticRegression
reg=LogisticRegression()
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#predicting the values for x_test

# %%
pred=reg.predict(x_test)

# %%
#I am importing classification_report from sklearn metrics to check the performance of the model

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       146
#            1       0.99      0.92      0.95       154
#
#     accuracy                           0.95       300
#    macro avg       0.95      0.95      0.95       300
# weighted avg       0.95      0.95      0.95       300

# %%
#The precison says 92% of predictions were correct.
#Recall says 99% of the positives were correcly identified.
#F1-score states 95% of positive predictions were correct.
#The model is 95% accurate.

# %%
#Also using the confusion matrix for checking th accuracy of the model.

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, pred))
# Out:
# [[144   2]
#  [ 13 141]]

# %%
#I predicted 2 positive and it’s false,that is predicted as clicking the Ad while it was not clicked.
#I predicted 13 negative and it's false,that is predicted as didn't click the Ad while it was clicked.
